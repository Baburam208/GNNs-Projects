# %% [markdown]
# # FER with GNNs using Undirected graph with self-loops

# %%
import torch
import os
import pandas as pd
from torch_geometric.data import InMemoryDataset, Data
from torch_geometric.utils.convert import to_networkx
import networkx as nx
from tqdm import tqdm

from torch_geometric.loader import DataLoader, DenseDataLoader

from torch_geometric.nn import DenseGCNConv as GCNConv

from math import ceil

# %%
class LandmarksToGraph(InMemoryDataset):
    def __init__(self, root, transform=None, pre_transform=None):
        super(LandmarksToGraph, self).__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])

    @property
    def processed_file_names(self):
        return 'data.pt'

    def process(self):
        src = os.path.join(self.raw_dir, 'train')
        edges_path = os.path.join(self.raw_dir, 'EDGES.txt')

        def make_undirected_graph_with_self_loops(edges_path):
            df_edge = pd.read_csv(edges_path, delimiter=',', header=None)
            edge_idx = torch.tensor(df_edge.to_numpy(), dtype=torch.int64)

            edge_index = edge_idx.tolist()
            for item in edge_index:
                x, y = item
                item_pair = [y, x]
                if item_pair in edge_index:
                    continue
                else:
                    edge_index.append(item_pair)
                    
            # Add self-loop
            for i in range(468):
                edge_index.append([i, i])
            
            return torch.tensor(edge_index, dtype=torch.int64).T

        edge_idx = make_undirected_graph_with_self_loops(edges_path)
        
        data_list = list()
        for idx, category in tqdm(enumerate(os.listdir(src))):
            file_path = os.path.join(src, category)
            
            for file in os.listdir(file_path):
                filename_path = os.path.join(file_path, file)
                
                df_file = pd.read_csv(filename_path, delimiter=',', header=None)
                
                df_label = idx
                
                # df_edge = pd.read_csv(edges_path, delimiter=',', header=None)
                            
                x = torch.tensor(df_file.to_numpy(), dtype=torch.float)
                # edge_idx = torch.tensor(df_edge.to_numpy().transpose(), dtype=torch.int64)
                
                y = torch.tensor(df_label, dtype=torch.int64)
                graph = Data(x=x, edge_index=edge_idx, y=y)
                data_list.append(graph)

        # Store the processed data
        data, slices = self.collate(data_list)
        torch.save((data, slices), self.processed_paths[0])

dataset = LandmarksToGraph(root='dataset2')
# Out:
# Processing...
# 7it [02:29, 21.39s/it]
# Done!

# %%
data = dataset[0]

# Print information about the dataset
print(f'Dataset: {dataset}')
print('-------------------')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of nodes: {data.x.shape[0]}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

# Print information about the graph
print(f'\nGraph:')
print('------')
print(f'Edges are directed?: {data.is_directed()}')
print(f'Graph has isolated nodes?: {data.has_isolated_nodes()}')
print(f'Graph has self.loops?: {data.has_self_loops()}')
# Out:
# Dataset: LandmarksToGraph(26622)
# -------------------
# Number of graphs: 26622
# Number of nodes: 468
# Number of features: 3
# Number of classes: 7
#
# Graph:
# ------
# Edges are directed?: False
# Graph has isolated nodes?: False
# Graph has self.loops?: True

# %% [markdown]
# ## Splitting the dataset into train, test and validation

# %%
n = (len(dataset) + 9) // 10
print(f"n: {n}")
print(f"2*n: {2*n}")

torch.manual_seed(1234)
dataset = dataset.shuffle()
n = (len(dataset) + 9) // 10
test_dataset = dataset[:n]
val_dataset = dataset[n:2 * n]
train_dataset = dataset[2 * n:]

test_loader = DataLoader(test_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=True)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
# Out:
# n: 2663
# 2*n: 5326

# %% [markdown]
# ## Train the network (GCNConv)

# %%
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch.nn import Flatten
from torch.nn import Linear
from torch_geometric.nn import global_mean_pool
import matplotlib.pyplot as plt

# %%
class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(dataset.num_node_features, 64)
        self.conv2 = GCNConv(64, 16)
        self.lin = Linear(16, dataset.num_classes)
        
    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        
        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]
        
        # 3. Apply a final classifier
        x = self.lin(x)
        
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GCN().to(device)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()
# Out:
# GCN(
#   (conv1): GCNConv(3, 64)
#   (conv2): GCNConv(64, 16)
#   (lin): Linear(in_features=16, out_features=7, bias=True)
# )

# %%
def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
    model.eval()
    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.

train_accuracy = list()
val_accuracy = list()
epochs = 200
for epoch in range(1, 201):
    train()
    train_acc = test(train_loader)
    val_acc = test(val_loader)
    train_accuracy.append(train_acc)
    val_accuracy.append(val_acc)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f} Validation Acc: {val_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.2595 Validation Acc: 0.2463
# Epoch: 002, Train Acc: 0.2595 Validation Acc: 0.2463
# Epoch: 003, Train Acc: 0.2595 Validation Acc: 0.2463
# Epoch: 004, Train Acc: 0.2595 Validation Acc: 0.2463
# Epoch: 005, Train Acc: 0.2595 Validation Acc: 0.2463
# Epoch: 006, Train Acc: 0.2604 Validation Acc: 0.2471
# Epoch: 007, Train Acc: 0.2631 Validation Acc: 0.2501
# Epoch: 008, Train Acc: 0.2693 Validation Acc: 0.2546
# Epoch: 009, Train Acc: 0.2708 Validation Acc: 0.2722
# Epoch: 010, Train Acc: 0.2648 Validation Acc: 0.2512
# Epoch: 011, Train Acc: 0.2727 Validation Acc: 0.2584
# Epoch: 012, Train Acc: 0.2863 Validation Acc: 0.2850
# Epoch: 013, Train Acc: 0.2883 Validation Acc: 0.2798
# Epoch: 014, Train Acc: 0.2887 Validation Acc: 0.2846
# Epoch: 015, Train Acc: 0.2892 Validation Acc: 0.2831
# Epoch: 016, Train Acc: 0.2881 Validation Acc: 0.2779
# Epoch: 017, Train Acc: 0.2877 Validation Acc: 0.2722
# Epoch: 018, Train Acc: 0.2705 Validation Acc: 0.2584
# Epoch: 019, Train Acc: 0.2901 Validation Acc: 0.2888
# Epoch: 020, Train Acc: 0.2926 Validation Acc: 0.2869
# Epoch: 021, Train Acc: 0.2834 Validation Acc: 0.2655
# Epoch: 022, Train Acc: 0.2901 Validation Acc: 0.2869
# Epoch: 023, Train Acc: 0.2822 Validation Acc: 0.2685
# Epoch: 024, Train Acc: 0.2829 Validation Acc: 0.2674
# Epoch: 025, Train Acc: 0.2827 Validation Acc: 0.2659
# Epoch: 026, Train Acc: 0.2903 Validation Acc: 0.2869
dataset.num_classes)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)

        x = global_mean_pool(x, batch)

        x = self.lin(x)
        return x

# %%
model = GNN().to(device)
print(model)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()
# Out:
# GNN(
#   (conv1): GraphConv(3, 64)
#   (conv2): GraphConv(64, 32)
#   (lin): Linear(in_features=32, out_features=7, bias=True)
# )

# %%
# %%time
def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         data = data.to(device)
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.


train_accuracy = list()
test_accuracy = list()
epochs = 200
for epoch in range(1, 201):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    train_accuracy.append(train_acc)
    test_accuracy.append(test_acc)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')

# Plotting
epoch = [i for i in range(1, 201)]
plt.plot(epoch, train_accuracy, label='train')
plt.plot(epoch, test_accuracy, label='test')
plt.legend()
plt.plot()
# Out:
# Epoch: 001, Train Acc: 0.2475, Test Acc: 0.2396
# Epoch: 002, Train Acc: 0.2574, Test Acc: 0.2569
# Epoch: 003, Train Acc: 0.2584, Test Acc: 0.2576
# Epoch: 004, Train Acc: 0.2596, Test Acc: 0.2614
# Epoch: 005, Train Acc: 0.2601, Test Acc: 0.2606
# Epoch: 006, Train Acc: 0.2604, Test Acc: 0.2606
# Epoch: 007, Train Acc: 0.2601, Test Acc: 0.2617
# Epoch: 008, Train Acc: 0.2674, Test Acc: 0.2617
# Epoch: 009, Train Acc: 0.2628, Test Acc: 0.2629
# Epoch: 010, Train Acc: 0.2636, Test Acc: 0.2685
# Epoch: 011, Train Acc: 0.2607, Test Acc: 0.2617
# Epoch: 012, Train Acc: 0.2628, Test Acc: 0.2647
# Epoch: 013, Train Acc: 0.2689, Test Acc: 0.2730
# Epoch: 014, Train Acc: 0.2629, Test Acc: 0.2640
# Epoch: 015, Train Acc: 0.2809, Test Acc: 0.2865
# Epoch: 016, Train Acc: 0.2854, Test Acc: 0.2820
# Epoch: 017, Train Acc: 0.2623, Test Acc: 0.2632
# Epoch: 018, Train Acc: 0.2773, Test Acc: 0.2805
# Epoch: 019, Train Acc: 0.2787, Test Acc: 0.2828
# Epoch: 020, Train Acc: 0.2630, Test Acc: 0.2625
# Epoch: 021, Train Acc: 0.2655, Test Acc: 0.2655
# Epoch: 022, Train Acc: 0.2743, Test Acc: 0.2722
# Epoch: 023, Train Acc: 0.2618, Test Acc: 0.2617
# Epoch: 024, Train Acc: 0.2638, Test Acc: 0.2632
# Epoch: 025, Train Acc: 0.2631, Test Acc: 0.2632
# Epoch: 164, Train Acc: 0.3428, Test Acc: 0.3440
# Epoch: 165, Train Acc: 0.3459, Test Acc: 0.3470
# Epoch: 166, Train Acc: 0.3511, Test Acc: 0.3511
# Epoch: 167, Train Acc: 0.3295, Test Acc: 0.3290
# Epoch: 168, Train Acc: 0.3491, Test Acc: 0.3413
# Epoch: 169, Train Acc: 0.3329, Test Acc: 0.3320
# Epoch: 170, Train Acc: 0.3370, Test Acc: 0.3462
# Epoch: 171, Train Acc: 0.3450, Test Acc: 0.3436
# Epoch: 172, Train Acc: 0.3477, Test Acc: 0.3436
# Epoch: 173, Train Acc: 0.3493, Test Acc: 0.3534
# Epoch: 174, Train Acc: 0.3433, Test Acc: 0.3477
# Epoch: 175, Train Acc: 0.3474, Test Acc: 0.3496
# Epoch: 176, Train Acc: 0.3468, Test Acc: 0.3526
# Epoch: 177, Train Acc: 0.3482, Test Acc: 0.3496
# Epoch: 178, Train Acc: 0.3476, Test Acc: 0.3477
# Epoch: 179, Train Acc: 0.3296, Test Acc: 0.3275
# Epoch: 180, Train Acc: 0.3427, Test Acc: 0.3443
# Epoch: 181, Train Acc: 0.3400, Test Acc: 0.3432
# Epoch: 182, Train Acc: 0.3477, Test Acc: 0.3455
# Epoch: 183, Train Acc: 0.3431, Test Acc: 0.3500
# Epoch: 184, Train Acc: 0.3488, Test Acc: 0.3451
# Epoch: 185, Train Acc: 0.3485, Test Acc: 0.3470
# Epoch: 186, Train Acc: 0.3432, Test Acc: 0.3443
# Epoch: 187, Train Acc: 0.3511, Test Acc: 0.3507
# Epoch: 188, Train Acc: 0.3556, Test Acc: 0.3567
# Epoch: 189, Train Acc: 0.3570, Test Acc: 0.3582
# Epoch: 190, Train Acc: 0.3478, Test Acc: 0.3530
# Epoch: 191, Train Acc: 0.3466, Test Acc: 0.3481
# Epoch: 192, Train Acc: 0.3465, Test Acc: 0.3470
# Epoch: 193, Train Acc: 0.3443, Test Acc: 0.3402
# Epoch: 194, Train Acc: 0.3460, Test Acc: 0.3477
# Epoch: 195, Train Acc: 0.3547, Test Acc: 0.3552
# Epoch: 196, Train Acc: 0.3527, Test Acc: 0.3485
# Epoch: 197, Train Acc: 0.3223, Test Acc: 0.3252
# Epoch: 198, Train Acc: 0.3519, Test Acc: 0.3526
# Epoch: 199, Train Acc: 0.3549, Test Acc: 0.3571
# Epoch: 200, Train Acc: 0.3414, Test Acc: 0.3466
# CPU times: total: 6min 2s
# Wall time: 11min 31s
# []

# %% [markdown]
# ## Train GraphSAGE

# %%
from torch_geometric.nn import SAGEConv
from torch_geometric.nn import global_mean_pool

class GraphSAGE(torch.nn.Module):
    """GraphSAGE"""
    def __init__(self, dim_in, dim_h, dim_out):
        super().__init__()
        self.sage1 = SAGEConv(dim_in, dim_h)
        self.sage2 = SAGEConv(dim_h, dim_out)
        self.optimizer = torch.optim.Adam(self.parameters(), lr=0.01, weight_decay=5e-4)
        self.lin = Linear(dim_out, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        h = self.sage1(x, edge_index)
        h = torch.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        h = self.sage2(h, edge_index)
        h = global_mean_pool(h, batch)
        h = self.lin(h)
        return h

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GraphSAGE(dataset.num_features, 64, 32).to(device)
print(model)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
# Out:
# GraphSAGE(
#   (sage1): SAGEConv(3, 64, aggr=mean)
#   (sage2): SAGEConv(64, 32, aggr=mean)
#   (lin): Linear(in_features=32, out_features=7, bias=True)
# )

# %%
def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
    model.eval()
    correct = 0
    for data in loader:  # Iterate in batches over the training/test/validation dataset.
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.

train_accuracy = list()
val_accuracy = list()
epochs = 200
for epoch in range(1, 201):
    train()
    train_acc = test(train_loader)
    val_acc = test(val_loader)
    train_accuracy.append(train_acc)
    val_accuracy.append(val_acc)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Validation Acc: {val_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.2614, Validation Acc: 0.2493
# Epoch: 002, Train Acc: 0.2759, Validation Acc: 0.2640
# Epoch: 003, Train Acc: 0.2788, Validation Acc: 0.2685
# Epoch: 004, Train Acc: 0.3049, Validation Acc: 0.3064
# Epoch: 005, Train Acc: 0.3109, Validation Acc: 0.3139
# Epoch: 006, Train Acc: 0.2899, Validation Acc: 0.2798
# Epoch: 007, Train Acc: 0.3001, Validation Acc: 0.2861
# Epoch: 008, Train Acc: 0.3185, Validation Acc: 0.3143
# Epoch: 009, Train Acc: 0.3239, Validation Acc: 0.3248
# Epoch: 010, Train Acc: 0.3107, Validation Acc: 0.3113
# Epoch: 011, Train Acc: 0.3044, Validation Acc: 0.2933
# Epoch: 012, Train Acc: 0.2733, Validation Acc: 0.2798
# Epoch: 013, Train Acc: 0.2926, Validation Acc: 0.2745
# Epoch: 014, Train Acc: 0.3223, Validation Acc: 0.3229
# Epoch: 015, Train Acc: 0.3264, Validation Acc: 0.3383
# Epoch: 016, Train Acc: 0.2771, Validation Acc: 0.2625
# Epoch: 017, Train Acc: 0.3032, Validation Acc: 0.2903
# Epoch: 018, Train Acc: 0.3259, Validation Acc: 0.3259
# Epoch: 019, Train Acc: 0.3183, Validation Acc: 0.3154
# Epoch: 020, Train Acc: 0.2879, Validation Acc: 0.2700
# Epoch: 021, Train Acc: 0.3185, Validation Acc: 0.3106
# Epoch: 022, Train Acc: 0.3275, Validation Acc: 0.3327
# Epoch: 023, Train Acc: 0.3014, Validation Acc: 0.3173
# Epoch: 024, Train Acc: 0.3295, Validation Acc: 0.3320
# Epoch: 025, Train Acc: 0.3317, Validation Acc: 0.3372
